# %%
import pandas as pd
import numpy as np

# %%
print(Hello Capstone Project Course!)
# Out:
#   File "<ipython-input-4-6fe37a878200>", line 1
#     print (Hello Capstone Project Course!)
#                         ^
# SyntaxError: invalid syntax
